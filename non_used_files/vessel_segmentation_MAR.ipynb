# %%
from src.utils import *
from src.config import NLMEANS_IMG_DIR, NLMEANS_IMG_DIR_2
from non_used_files.vessel_segmentation import *
#

# %%
# Group all paths by serie and pick one randomly to test
paths = get_all_image_paths(NLMEANS_IMG_DIR)
series = group_paths_by_serie(paths)
print(f"Total series found: {len(series)}")

random_serie_key = random.choice(list(series.keys()))
random_serie_paths = series[random_serie_key]

# get 5 subjects
random_series_keys = random.sample(list(series.keys()), k=min(5, len(series)))

print(f"Selected serie : {random_serie_key}")
print(f"Frames in serie: {len(random_serie_paths)}")
# Out:
# Total images found: 8325
# Total series found: 214
# Selected serie : 012/4
# Frames in serie: 23

# %% [markdown]
# ### FRANGI FILTER

# %%
selected_series = {k: series[k] for k in random_series_keys}

browse_frangi_interactive(selected_series)
# Out:
# Loading preprocessed frames…
# Done. Use sliders to explore Frangi parameters.
# interactive(children=(Dropdown(description='Serie', options=('066/8', '084/9', '023/4', '007/3', '021/35'), va…

# %%
# Group all paths by serie and pick one randomly to test
paths_2 = get_all_image_paths(NLMEANS_IMG_DIR_2)
series_2 = group_paths_by_serie(paths_2)
print(f"Total series found: {len(series_2)}")

random_serie_key_2 = random.choice(list(series_2.keys()))
random_serie_paths_2 = series_2[random_serie_key_2]

# get 5 subjects
random_series_keys_2 = random.sample(list(series_2.keys()), k=min(5, len(series_2)))

print(f"Selected serie : {random_serie_key_2}")
print(f"Frames in serie: {len(random_serie_paths_2)}")
# Out:
# Total images found: 8325
# Total series found: 214
# Selected serie : 017/1
# Frames in serie: 36

# %%
selected_series_2 = {k: series_2[k] for k in random_series_keys_2}

# %%
browse_frangi_interactive(selected_series_2)
# Out:
# Loading preprocessed frames…
# Done. Use sliders to explore Frangi parameters.
# interactive(children=(Dropdown(description='Serie', options=('022/2', '070/3', '031/5', '007/5', '095/7'), val…
