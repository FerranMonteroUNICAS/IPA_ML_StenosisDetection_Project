# %%
# Enable automatic reloading of modified scripts
# %load_ext autoreload
# %autoreload 2

# %%
from src.utils import *
import random

paths = get_all_image_paths()
random_path = random.choice(paths)

img = load_image(random_path)
boxes = parse_stenosis_xml(get_xml_path(random_path))

# Use the generalizable function
img_annotated = draw_bboxes(img, boxes)
im_show(img_annotated, title="Patient Stenosis Check", figsize=(6, 6))
# Out:
# Total BMP images found: 8325
