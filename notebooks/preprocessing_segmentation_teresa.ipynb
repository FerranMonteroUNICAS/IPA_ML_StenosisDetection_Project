# %%
import random
import matplotlib.pyplot as plt

from pathlib import Path

from src.utils import *
from src.preprocessing import *
from src.preprocessing_teresa import *

# %%
# ------------------------------------------------------------
# Load dataset
# ------------------------------------------------------------
SEED = 42
paths = get_all_image_paths()

series = group_paths_by_serie(paths)

print(f"Total sessions found: {len(series)}")
# Out:
# Total images found: 8325
# Total sessions found: 214

# %% [markdown]
# browse_static_subtraction_grid(
#     series,
#     n=4,
#     seed=SEED
# )

# %% [markdown]
# browse_mean_denoising_grid(
#     series,
#     n=4,
#     seed=SEED
# )

# %% [markdown]
# browse_median_denoising_grid(
#     series,
#     n=4,
#     seed=SEED
# )

# %% [markdown]
# browse_mean_clahe_grid(
#     series,
#     n=4,
#     seed=SEED
# )

# %% [markdown]
# browse_median_clahe_grid(
#     series,
#     n=4,
#     seed=SEED
# )

# %%
browse_median_frangi_grid(
    series,
    n=4,
    seed=SEED
)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='Sigma 1', max=5.0, min=0.5, step=0.5), FloatSlider(v…

# %%
browse_mean_frangi_grid(
    series,
    n=4,
    seed=SEED
)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='Sigma 1', max=5.0, min=0.5, step=0.5), FloatSlider(v…
